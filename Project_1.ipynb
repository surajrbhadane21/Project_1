# %% [markdown]
# # Extract 3200 tweets of given user (@DonalMurphy)

# %%
import tweepy as tw
import csv
from textblob import TextBlob
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Twitter Authentication

# %%
consumer_key=    '6T4eYCxVY1u7DcL1zdahhmco9'                          # input("consumer_key        :- ")               
consumer_secret=  'gukG6TWYl4ha4falNcwBnm7ZLFdgO2H5dGIcBhVnlrSv5CBpfP'  # input("consumer_secret     :- ")              
access_token=      '874662506425405440-5I0oHSBsOfcpa9nJncAW1cjcBSbaaek' # input("access_token        :- ")              
access_token_secret='XaaQsGb8Cu2vfkK8zF8okSCXdhU1QLlltYiOQE8lk1hXt'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True) #wait_on_rate_limit=True

# %% [markdown]
# ## 3200 tweets of DonalMurphy
#       with 17 variables :-
#       1.  Tweet ID
#       2.  Username
#       3.  Tweet
#       4.  Presense of Link
#       5.  Time
#       6.  Tweet Type
#       7.  Reply to
#       8.  Reweeted BY
#       9.  Number Of Retweets
#       10. Hashtags
#       11. Mentions
#       12. Names
#       13. Number Of Tweets
#       14. Number Of Followers
#       15. Number Following
#       16. Number Of Links
#       17. Number of Comments

# %%
tweets = tw.Cursor(api.user_timeline,id="@1DonalMurphy",lang="eng",include_rts=True,since='2020-04-23').items(3200)
users_locs = [[tweet.user.screen_name, tweet.id,tweet.retweet_count,tweet.user.location, tweet.text, tweet.user.followers_count,tweet.favorite_count,tweet.created_at,tweet.in_reply_to_screen_name, tweet.__hash__] for tweet in tweets]
users_locs
# Out:
# [['1DonalMurphy',
#   1367922431143391238,
#   0,
#   'New Ross, Co Wexford, Ireland',
#   'A fair punishment. I thought Elliott\'s statement since was particularly strong. \n"With my position in the sport I h… https://t.co/PbziuS0jxz',
#   2174,
#   18,
#   datetime.datetime(2021, 3, 5, 19, 38, 17),
#   None,
#   None],
#  ['1DonalMurphy',
#   1367818544096960515,
#   0,
#   'New Ross, Co Wexford, Ireland',
#   "@deniscoakley11 @ihrb_ie Scrutiny, fines and bans is 'no deterrent' to Byrnes it seems.",
#   2174,
#   0,
#   datetime.datetime(2021, 3, 5, 12, 45, 28),
#   'deniscoakley11',
#   None],
#  ['1DonalMurphy',
#   1367812404919361538,
#   0,
#   'New Ross, Co Wexford, Ireland',
#   '@deniscoakley11 @ihrb_ie He should have got a total disqualification because this transfer of horses is making the… https://t.co/dPwSfOogBM',
#   2174,
#   2,
#   datetime.datetime(2021, 3, 5, 12, 21, 4),
#   'deniscoakley11',
#   None],
#  ['1DonalMurphy',
#   1367806480662069256,
#   4,
# ...

# %%
print(dir(tw.User))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'follow', 'followers', 'followers_ids', 'friends', 'lists', 'lists_memberships', 'lists_subscriptions', 'parse', 'parse_list', 'timeline', 'unfollow']

# %%
tweet_text = pd.DataFrame(data=users_locs,columns=['user','Tweet Id','No of Retweets',"location",'tweets','followers','likes','time','Mention','Hashtags'])
tweet_text
# Out:
#               user             Tweet Id  No of Retweets  \
# 0     1DonalMurphy  1367922431143391238               0
# 1     1DonalMurphy  1367818544096960515               0
# 2     1DonalMurphy  1367812404919361538               0
# 3     1DonalMurphy  1367806480662069256               4
# 4     1DonalMurphy  1367500159140126723               0
# ...            ...                  ...             ...
# 3186  1DonalMurphy   646786743685877760               8
# 3187  1DonalMurphy   646711708665442305               0
# 3188  1DonalMurphy   646709740509265920               0
# 3189  1DonalMurphy   646702035677675520               0
# 3190  1DonalMurphy   646675094174068736               1
#
#                            location  \
# 0     New Ross, Co Wexford, Ireland
# 1     New Ross, Co Wexford, Ireland
# 2     New Ross, Co Wexford, Ireland
# 3     New Ross, Co Wexford, Ireland
# 4     New Ross, Co Wexford, Ireland
# ...                             ...
# ...
